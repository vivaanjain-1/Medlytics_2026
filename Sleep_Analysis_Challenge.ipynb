# %% [markdown]
# <a href="https://colab.research.google.com/github/vivaanjain-1/Medlytics_2026/blob/main/Sleep_Analysis_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # "You Snooze, You Win" Challenge
#
# Every year, the [PhysioNet/CinC (Computing in Cardiology) Challenge](https://www.physionet.org/challenge/) invites "participants to tackle clinically interesting problems that are either unsolved or not well-solved." For this year's week 2 machine learning challenge, BWSI has revived a past PhysioNet challenge based on sleep classification.
#
# This year's challenge focuses on the classification of nonarousal and arousal timeframes. If you would like to understand the biological implications of the challenge, we recommend reading PhysioNet's [introduction](https://physionet.org/challenge/2018/) of the challenge.
#
# For this challenge, you will classify samples into 5 classes (Arousal, NREM1, NREM2, NREM3, REM). Each sample consists of seven physiological signals (O2-M1, E1-M2, Chin1-Chin2, ABD, CHEST, AIRFLOW, ECG) measured at 200 Hz over a 60 second period (12000 timepoints). In this notebook, we provide code to import the data, visualize sample signals, implement an example classifier, and 'score' your model.

# %%
### Import libraries ###

from google.colab import files
import matplotlib.pyplot as plt
import matplotlib

#set default plotting fonts
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 20}

matplotlib.rc('font', **font)

import numpy as np
import os
import pandas as pd
import random
from sklearn import metrics
from sklearn.utils import shuffle
import tensorflow as tf

# %% [markdown]
# ## Loading the Dataset
#
# This dataset is a modified version of the PhysioNet/CinC Challenge data, which were contributed by the Massachusetts General Hospital’s Computational Clinical Neurophysiology Laboratory, and the Clinical Data Animation Laboratory.
# ***
# **Class labels:**
# - 0 = Arousal
# - 1 = NREM1
# - 2 = NREM2
# - 3 = NREM3
# - 4 = REM
# ***
# **Class descriptions:**
#
# <img src="https://github.com/BeaverWorksMedlytics2020/Data_Public/blob/master/Images/Week2/sleepStagesTable.svg?raw=true">
#
# ***
# **Physiological signal description:**
#
# O2-M1 - posterior brain activity (electroencephalography)
#
# E1-M2 - left eye activity (electrooculography)
#
# Chin1-Chin2 - chin movement (electromyography)
#
# ABD - abdominal movement (electromyography)
#
# CHEST - chest movement (electromyography)
#
# AIRFLOW - respiratory airflow
#
# ECG - cardiac activity (electrocardiography)
# ***
# Run both cell blocks to get the challenge data.

# %%
# Clone repo and move into data directory (only run this once)
# !git clone https://github.com/BeaverWorksMedlytics2020/Data_Public
os.chdir('./Data_Public/ChallengeProjects/Week2/')
# Out:
# Cloning into 'Data_Public'...
# remote: Enumerating objects: 5338, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (50/50), done.
# ^C
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8130/2027259534.py in <cell line: 0>()
#       1 # Clone repo and move into data directory (only run this once)
#       2 get_ipython().system('git clone https://github.com/BeaverWorksMedlytics2020/Data_Public')
# ----> 3 os.chdir('./Data_Public/ChallengeProjects/Week2/')
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data_Public/ChallengeProjects/Week2/'

# %% [markdown]
# ## Loading Data in Memory
# Run the cell below to extract the raw training and test data. It may take a minute or two to run through. Here are the variables containing the data you will get:
#
# * **data_train**: np array shape (4000, 12000, 7). Contains 4000 samples (60s each) of 12000 data points (200Hz x 60s), for 7 different signals.
# * **labels_train**: np array shape (4000,). Contains ground truth labels for data_train. The order of the labels corresponds to the order of the training data.
# * **ID_train**: list of 4000 unique IDs. The order of the IDs corresponds to the order of the training data.
# * **data_test**: np array shape (1000, 12000, 7). Contains 1000 samples (60s each) of 12000 data points (200Hz x 60s), for 7 different signals.
# * **ID_test**: list of 1000 unique IDs. The order of the IDs corresponds to the order of the training data.
#
# We encourage you to print each of these variables to see what they look like.

# %%
### Run once to import data ###

def get_file_locs():
    '''
    find all files in 'training' and 'test' directories and put their names
    under 'training' and 'test' keys in the file_dict dictionary
    '''

    file_dict = {'training':[], 'test':[]}
    for data_type in file_dict:
        for file in os.listdir('./' + data_type):
            file_dict[data_type].append(data_type + '/' + file)

    return file_dict

def get_sample_data(data_type, id_number):
    '''
    get signal data, label, and filename associated with given data type and index num

    parameters:

     data_type -- Dictates whether sample comes from training set or test set.
                 This input must be either 'training' or 'test' (defaults to 'training')

     id_number -- Which sample ID should be returned? Must be 0-3999 if data_type is 'training'
                 or 0-999 if data_type is 'test' (defaults to random integer from 0-999)

    returns:

     sample_data -- dataframe with 1 row and 2 columns-- column "Signal" contains a series object
                    and column "Label" contains numeric label for that sample
    '''
    file = './' + data_type + '/' + str(id_number) + '.xz'

    #sample_data is a dataframe with 1 row and 2 columns--
    #"Signal" (contains a series object) and "Label" (contains numeric label)
    sample_data = pd.read_pickle('./' + file)

    return sample_data, file.split('/')[2]

file_dict = get_file_locs()
print(f"{len(file_dict['training'])} training samples found, {len(file_dict['test'])} test samples found")

data_train = np.zeros((4000, 12000, 7))
labels_train = np.zeros(4000)
ID_train = []
for i in range(4000):
  sample_data, ID = get_sample_data('training', i)
  data_train[i] = np.array(list(sample_data['Signal']), dtype=float).reshape(12000, 7)
  labels_train[i] = np.array(list(sample_data['Label']), dtype=float)
  ID_train.append(ID)
  if(i%500==0):
    print('Loading training sample ' + str(i))

data_test = np.zeros((1000, 12000, 7))
ID_test = []
for i in range(1000):
  sample_data, ID = get_sample_data('test', i)
  data_test[i] = np.array(list(sample_data['Signal']), dtype=float).reshape(12000, 7)
  ID_test.append(ID)
  if(i%500==0):
    print('Loading test sample ' + str(i))

#keep original copy of data_train, labels_train, ID_train, data_test, and ID_test
# (for plotting or reference in case variables are shuffled later on)
data_train_orig = data_train.copy()
labels_train_orig = labels_train.copy()
ID_train_orig = ID_train.copy()
data_test_orig = data_test.copy()
ID_test_orig = ID_test.copy()

# %% [markdown]
# ## Data Visualization
#
# Run the cell below to visualize the raw data for a single 60s sample for all 7 signals. We strongly urge you to visualize a few different samples to get a feel for how the data looks and how much each signal can vary in amplitude and frequency from sample to sample. You can change which sample is being visualized by changing the arguments to the graph_signals call.

# %%
### Define some useful functions to retrieve and plot data from individual samples ###

""" Initalize key reference dictionaries """
sig_dict = {0:'O2-M1', 1:'E1-M2', 2:'Chin1-Chin2', 3:'ABD', 4:'CHEST', 5:'AIRFLOW', 6:'ECG'}
sig_type_dict = {0:'Time (s)', 1:'Frequency (Hz)'}
stage_dict = {0:'Arousal', 1:'NREM1', 2:'NREM2', 3:'NREM3', 4:'REM'}

def graph_signals(data_type = 'training', id_number = None):
    '''
    Create a graph of multiple signals, with rows representing signal class, and
    columns representing signal domain (i.e. time or frequency)

    inputs:

      parameters:

      data_type -- Dictates whether sample comes from training set or test set.
                 This input must be either 'training' or 'test' (defaults to 'training')

      id_number -- Which sample ID should be returned? Must be 0-3999 if data_type is 'training'
                 or 0-999 if data_type is 'test' (defaults to random integer from 0-999)

    '''

    assert data_type in ['test','training'], 'data_type should be either "test" or "training"'

    if id_number is None:
      if data_type == 'training':
        id_number = random.randint(0,3999)
      else:
        id_number = random.randint(0,999)

    #set time_signal_y based on 'test' or 'training' input
    if data_type == 'training':
        time_signal_y = data_train_orig[id_number,:,:]
    else:
        time_signal_y = data_test_orig[id_number,:,:]

    #Get signal values in time domain from either data_train_orig, or data_test_orig
    time_signal_x = np.arange(0, 60, step = 1/200) #this time axis doesn't change

    #Use time-domain signals to get frequency domain signals
    num_datapoints = time_signal_x.shape[0]
    freq_signal_x = np.arange(num_datapoints//2 + 1)/60
    freq_signal_y = np.ndarray(shape = (num_datapoints//2 + 1, 7))
    freq_signal_y = np.abs(np.fft.rfft(time_signal_y, axis = 0))

    plt.figure(figsize = (20, 18))
    title_list = ['time domain', 'freq domain']
    for signal_index in range(7): #7 classes of signal (O2-M1, E2-M2, etc.)
        for signal_domain_index in range(2): #2 types of signal (time and freq domain)
            plt.subplot(7, 2, 2*signal_index + signal_domain_index + 1)
            if signal_index==0:
                plt.title(title_list[signal_domain_index])
            if signal_domain_index == 0: #plot time domain signal
                plt.plot(time_signal_x, time_signal_y[:,signal_index])
            if signal_domain_index == 1: #plot freq domain signal
                plt.plot(freq_signal_x, freq_signal_y[:,signal_index])
            plt.ylabel(sig_dict[signal_index])
        plt.xlabel(sig_type_dict[signal_domain_index])
    plt.show()

# We can now use the above functions to retrieve data for a single sample
# (in the test or training set) and then plot it

#change these 2 lines to plot different samples (note that test set only has 1000 samples)
data_type = 'training'
id_number = random.randint(0,3999)

#print signal ID and the sample label (if known)
if data_type == 'training':
    print(data_type.title(), str(id_number), '(' + stage_dict[id_number//800] + ')')
else:
    print(data_type.title(), str(id_number), '(Unknown)')

#plot data from this sample
graph_signals(data_type = data_type, id_number = id_number)

# %% [markdown]
# ## Example Classifier
#
# Below is an example of a mediocre classifier for this dataset. It is a simple neural network that uses the spectral flatness of all signal classes its input features--that is, it has 7 input features.
#
# While the example classifier makes use of a neural network, we encourage you to utilize any ML algorithm that you feel would be appropriate.

# %%
### Define functions that calculate the features of a single sample ###

import scipy.stats.mstats as mstats

#I'm going to use spectral_flatness of the fft as a feature that could be used

#ADDED CODE spec rolloff and  bandwidth methods

def spectral_rolloff(ft, f_s):
    # Generate the frequencies associated with the fourier transform values
    num_samples = len(ft) # <-- UPDATE THESE LINES
    freqs = np.fft.fftfreq(num_samples, d = 1/f_s)       # <--

    # Grab the magnitude of the relevant part of the fourier transform values
    freqs = freqs[:num_samples//2]       # <-- UPDATE THESE LINES
    magnitude = np.abs(ft[:num_samples//2])   # <--

    # Compute the sum of *all* the fourier transform magnitudes
    whole_sum = np.sum(magnitude)   # <-- UPDATE THIS LINE

    # Initialize a variable to hold the cumulative sum of the magnitudes of the
    # fourier transform as we loop over it.
    cumulative_sum = 0.0

    # Loop over each element in the fourier transform
    for k, ft_mag in enumerate(magnitude):
        # Add the current magnitude of the cumulative sum
        cumulative_sum += ft_mag     # <-- UPDATE THIS LINE

        # Check if the cumulative sum is currently greater than 85% of the
        # whole sum, and return the frequency at which this inequality first
        # becomes true.
        if cumulative_sum >= 0.85*whole_sum:
            return freqs[k]

def spec_bandwidth_extractor(ft, f_s):
    """The cool feature extractor I wrote"""
    num_samples = len(ft)
    freqs = np.fft.fftfreq(num_samples, d=1/f_s)

    #get pos freqs only
    freqs = freqs[:num_samples//2]
    mag = np.abs(ft[:num_samples//2] * (2/num_samples))

    centroid = np.sum(mag * freqs) / np.sum(mag)

    spec_band = np.sqrt(np.sum(mag * (freqs - centroid) ** 2) / np.sum(mag))

    return spec_band

def max_freq(ft, f_s):
    num_samples = len(ft)
    freqs = np.linspace(0, f_s, num_samples)

    freqs = freqs[1:num_samples//2]
    mag = np.abs(ft[1:num_samples//2]) * (2/num_samples)

    max_ind = np.argmax(mag)
    max_frequency = freqs[max_ind]

    return max_frequency


def spectral_flatness(fft, zero_thresh = None):
  N = len(fft)
  magnitude = abs(fft[:N//2])* 2 / N

  if(zero_thresh is not None):
      magnitude[magnitude < zero_thresh] = zero_thresh

  if(any(magnitude<zero_thresh)):
    raise ValueError("THis shouldn't happen")

  sf = mstats.gmean(magnitude) / np.mean(magnitude)

  return sf

def spectral_centroid(ft, f_s):
    num_samples = len(ft)
    freqs = np.linspace(0, f_s, num_samples)
    freqs = freqs[0:num_samples//2]
    magnitude = np.abs(ft[0:num_samples//2]) * (2/num_samples)
    spec_centroid = np.sum(magnitude*freqs)/np.sum(magnitude)
    return spec_centroid

def zero_crossing_rate(ft):
    y = np.fft.ifft(ft).real
    zcr = np.sum(np.diff(np.sign(y)) != 0) / len(y)
    return zcr


def get_features_for_single_sample(data_type = 'training', id_number = None):
    '''
    Calculate some number feature values for a single sample

    parameters:

      data_type -- Dictates whether sample comes from training set or test set.
                 This input must be either 'training' or 'test' (defaults to 'training')

      id_number -- Which sample ID should be returned? Must be 0-3999 if data_type is 'training'
                 or 0-999 if data_type is 'test' (defaults to random integer from 0-999)

    returns:

      feature_vector -- 1d array containing all feature values for this sample
    '''

    assert data_type in ['test','training'], 'data_type should be either "test" or "training"'

    if id_number is None:
        id_number=random.randint(0,999)

    if data_type == 'training':
        time_signal_y = data_train_orig[id_number,:,:]
    else:
        time_signal_y = data_test_orig[id_number,:,:]

    #---Populate feature vector ---
    #(Example uses spectral flatness, but you can populate feature_vector with
    # anything that seems useful)

    #get an fft for all signals in this sample
    fft_arr = np.fft.rfft(time_signal_y, axis = 0)

    #Initialize feature vector to zeros of right size
    feature_vector = np.zeros((time_signal_y.shape[1] * 7, 1))

    #Enumerate over all classes of signal, calculate features for each and append value to feature_vector
    for ind in range(fft_arr.shape[1]):
        feature_vector[ind*7] = spectral_flatness(fft_arr[:,ind], zero_thresh = 10**-10)
        feature_vector[ind*7 + 1] = spectral_centroid(fft_arr[:,ind], 200)
        feature_vector[ind*7 + 2] = zero_crossing_rate(fft_arr[:,ind])
        feature_vector[ind*7 + 3] = spectral_rolloff(fft_arr[:,ind], 200)
        feature_vector[ind*7 + 4] = spec_bandwidth_extractor(fft_arr[:,ind], 200)
        feature_vector[ind*7 + 5] = max_freq(fft_arr[:,ind], 200)
        feature_vector[ind*7 + 6] = np.std(time_signal_y[:, ind])

    #---Finished populating feature vector---
    #(now feature_vector is populated with hand-engineered features for this sample)

    return feature_vector

def get_features(data_type, num_samples):
    '''
    Retrieve features from num_samples samples in either test or training set,
    return features for each sample and index of each sample

    inputs:

      data_type -- Dictates whether sample comes from training set or test set.
                 This input must be either 'training' or 'test' (defaults to 'training')

      num_samples -- For how many samples should features be calculated?
                  (should not exceed total samples in a given data_type)

    returns:

      features -- n x p array of feature values for all samples where rows
                  correspond to samples and columns correspond to feature number

      order -- 1d array where index i contains the index of row i of the feature vector
               (only needed if shuffling takes place later)
    '''

    features, order = np.array([]), np.array([])
    for i in range(num_samples):
        single_sample_features = get_features_for_single_sample(data_type = data_type, id_number = i)
        features = np.hstack((features, single_sample_features)) if features.size else single_sample_features
        order = np.append(order, i).astype(np.float32)

    #ensure features are of type float32
    features = features.astype(np.float32)

    return np.transpose(features), order

# %%
### Run every time you modify your feature extraction ###

print('calculating features for training data...')
train_data, train_order = get_features('training', 4000)
train_data = np.nan_to_num(train_data)

print('calculating features for test data...')
test_data, test_order = get_features('test', 1000)
test_data = np.nan_to_num(test_data)
# Out:
# calculating features for training data...
# /tmp/ipykernel_8130/514556094.py:83: RuntimeWarning: invalid value encountered in scalar divide
#   spec_centroid = np.sum(magnitude*freqs)/np.sum(magnitude)
# /tmp/ipykernel_8130/514556094.py:45: RuntimeWarning: invalid value encountered in scalar divide
#   centroid = np.sum(mag * freqs) / np.sum(mag)
# calculating features for test data...

# %%
#normalize? ADDED CODE
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)

# %% [markdown]
# ## Visualize Entire Dataset's Features

# %%
### Create label array for all training samples using categorical datatype ###

train_labels = np.ndarray(shape = (1, 4000))

#set labels to integers first
for i in range(4000):
    train_labels[0][i] = i//800 # This is a way to label each entry (since classes are in order)

#convert labels to onehot, ensure type is float32
train_labels = tf.keras.utils.to_categorical(train_labels[0], 5)
train_labels = train_labels.astype(np.float32)

# %%
### Run whenever you want to check or view your data and labels ###
print(f"train_data.shape = {train_data.shape} \n train_labels.shape = {train_labels.shape}\n\n")
print(f"train data:\n {train_data}\n\ntrain labels:\n {train_labels}")
#plot feature values and label values to show data clearly
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize= (30,15))

#Note: if your features are not scaled to the range 0->1 you might want to change vmin and vmax
featureImg = ax1.imshow(train_data[:,:], aspect = 'auto', interpolation = 'None', vmin = -3, vmax = 3)# vmin = 0, vmax = 1.0)
ax1.set_title('Feature Values')
ax1.set_ylabel('Sample Number')
ax1.set_xlabel('Feature Number')
fig.colorbar(featureImg, ax = ax1, boundaries = np.linspace(-3.0, 3.0, 50), ticks = [-3,0,3])
plt.figure(figsize=(4,3))

from matplotlib.colors import ListedColormap
bw_cmap = ListedColormap(np.array([[0,0,0,1],[1,1,1,1]])) # make a colormap manually
labelImg = ax2.imshow(train_labels, aspect = 'auto', cmap = bw_cmap,interpolation = 'None', vmin = 0, vmax = 1.0)
ax2.set_title('Label Values')
ax2.set_xlabel('Label')
ax2.set_xticks(range(len(stage_dict)))
ax2.set_xticklabels([stage_dict[i] for i in range(len(stage_dict))])
fig.colorbar(labelImg, ax = ax2, boundaries = np.linspace(-0.5, 1.5,3), ticks = [0, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8130/2586625861.py in <cell line: 0>()
#       1 ### Run whenever you want to check or view your data and labels ###
# ----> 2 print(f"train_data.shape = {train_data.shape} \n train_labels.shape = {train_labels.shape}\n\n")
#       3 print(f"train data:\n {train_data}\n\ntrain labels:\n {train_labels}")
#       4 #plot feature values and label values to show data clearly
#       5 fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize= (30,15))
#
# NameError: name 'train_data' is not defined

# %%
#### Run every time you modify your feature extraction ###
#
# This cell splits up the labeled data into 3 subsets (training data, validation
# data, and test data)
#
# This 3-way split is very common in training a supervised learning model. The purpose of
# each partition is as follows:
#
# 1) Training data is used to adjust model weights (so-called model parameters)
# 2) Validation data is used to gauge how well model generalizes (allowing user
#    to compare between different trained models and/or non-trained model
#    parameters (hyperparameters))
# 3) Test data is used to provide an indicator of real-world performance (it
#    should not be used when deciding between models because this would result
#    in overfitting!)

train_data_shuffled, train_labels_shuffled = shuffle(train_data, train_labels, random_state = 25)

""" val_size (int) must be from 0-4000 """
val_size = 1000
mocktest_size = 500

val_data = train_data_shuffled[:val_size]
mocktest_data = train_data_shuffled[val_size:val_size + mocktest_size]
partial_train_data = train_data_shuffled[val_size + mocktest_size:]

val_labels = train_labels_shuffled[:val_size]
mocktest_labels = train_labels_shuffled[val_size:val_size + mocktest_size]
partial_train_labels = train_labels_shuffled[val_size + mocktest_size:]

training_set = tf.data.Dataset.from_tensor_slices((partial_train_data, partial_train_labels))
training_set = training_set.batch(40) #set batch size

# %%
from sklearn.ensemble import RandomForestClassifier
train_labels_int = np.argmax(train_labels, axis=1)
random_forest = RandomForestClassifier(n_estimators=500)
random_forest.fit(train_data, train_labels_int)
train_labels_pred = random_forest.predict(train_data)
val_labels_pred = random_forest.predict(val_data)

# %%
#feature importances
signal_dict = {0:'02-M1', 1: 'E1-M2', 2:'Chin1-Chin2', 3:'ABD', 4:'CHEST', 5:'AIRFLOW', 6:'ECG'}
feature_labels = ['spectral_flatness', 'spectral_centroid', 'zero_crossing_rate',
                  'spectral_rolloff', 'spectral_bandwidth', 'max_freq', 'std']

feature_names = [f"{signal_dict[sig_idx]}_{feature_labels[feat_idx]}"
                 for sig_idx in range(7)
                 for feat_idx in range(7)]

importances = random_forest.feature_importances_

sorted_index = np.argsort(importances)[::-1]
sorted_importances = importances[sorted_index]
sorted_names = [feature_names[i] for i in sorted_index]

plt.figure(figsize=(12,14))
plt.barh(range(len(sorted_importances)), sorted_importances[::-1])
plt.yticks(range(len(sorted_importances)), sorted_names[::-1], fontsize=10)
plt.xlabel('Feature Importance')
plt.title('Random Forest Feature Importances')
plt.tight_layout()
plt.show()

# %%
### Run every time you change set of parameters ###

model = tf.keras.Sequential()

""" Modify to your heart's and algorithm's content ^_^ """

model.add(tf.keras.layers.Input(shape=(train_data.shape[1],)))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(64, activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(32, activation=tf.nn.relu))
# we should end with a softmax to ensure outputs behave like probabilities
#(i.e. sum to 1)
model.add(tf.keras.layers.Dense(5, activation=tf.nn.softmax))

opt = tf.keras.optimizers.RMSprop(learning_rate=0.00005)
#Another potential optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         6,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,901 (66.02 KB)
#  Trainable params: 16,901 (66.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
### Run whenever you want to train and validate your model ###

"""
EPOCHS (int) the number of times the optimization algorithm passes
through the full dataset (calculating errors and derivatives) to update weights
(One pass through the data is called an "epoch")
"""

EPOCHS = 100

for epoch in range(EPOCHS):
    for signals, labels in training_set:
        tr_loss, tr_accuracy = model.train_on_batch(signals, labels)
    val_loss, val_accuracy = model.evaluate(val_data, val_labels)
    print(('Epoch #%d\t Training Loss: %.2f\tTraining Accuracy: %.2f\t'
         'Validation Loss: %.2f\tValidation Accuracy: %.2f')
         % (epoch + 1, tr_loss, tr_accuracy,
         val_loss, val_accuracy))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3820 - loss: 1.4672
# Epoch #1	 Training Loss: 1.64	Training Accuracy: 0.27	Validation Loss: 1.47	Validation Accuracy: 0.38
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4420 - loss: 1.3416
# Epoch #2	 Training Loss: 1.45	Training Accuracy: 0.39	Validation Loss: 1.34	Validation Accuracy: 0.44
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4910 - loss: 1.2466
# Epoch #3	 Training Loss: 1.34	Training Accuracy: 0.44	Validation Loss: 1.25	Validation Accuracy: 0.49
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5190 - loss: 1.1742
# Epoch #4	 Training Loss: 1.25	Training Accuracy: 0.49	Validation Loss: 1.17	Validation Accuracy: 0.52
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5360 - loss: 1.1353
# Epoch #5	 Training Loss: 1.21	Training Accuracy: 0.51	Validation Loss: 1.14	Validation Accuracy: 0.54
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5510 - loss: 1.1105
# Epoch #6	 Training Loss: 1.15	Training Accuracy: 0.54	Validation Loss: 1.11	Validation Accuracy: 0.55
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5640 - loss: 1.0973
# Epoch #7	 Training Loss: 1.12	Training Accuracy: 0.55	Validation Loss: 1.10	Validation Accuracy: 0.56
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5640 - loss: 1.0849
# Epoch #8	 Training Loss: 1.10	Training Accuracy: 0.56	Validation Loss: 1.08	Validation Accuracy: 0.56
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5680 - loss: 1.0747
# Epoch #9	 Training Loss: 1.08	Training Accuracy: 0.57	Validation Loss: 1.07	Validation Accuracy: 0.57
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5730 - loss: 1.0704
# Epoch #10	 Training Loss: 1.05	Training Accuracy: 0.59	Validation Loss: 1.07	Validation Accuracy: 0.57
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5840 - loss: 1.0577
# Epoch #11	 Training Loss: 1.06	Training Accuracy: 0.58	Validation Loss: 1.06	Validation Accuracy: 0.58
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5870 - loss: 1.0543
# Epoch #12	 Training Loss: 1.03	Training Accuracy: 0.59	Validation Loss: 1.05	Validation Accuracy: 0.59
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5870 - loss: 1.0411
# Epoch #13	 Training Loss: 1.03	Training Accuracy: 0.60	Validation Loss: 1.04	Validation Accuracy: 0.59
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5920 - loss: 1.0361
# Epoch #14	 Training Loss: 1.01	Training Accuracy: 0.60	Validation Loss: 1.04	Validation Accuracy: 0.59
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5880 - loss: 1.0346
# Epoch #15	 Training Loss: 1.01	Training Accuracy: 0.61	Validation Loss: 1.03	Validation Accuracy: 0.59
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5900 - loss: 1.0255
# Epoch #16	 Training Loss: 1.00	Training Accuracy: 0.60	Validation Loss: 1.03	Validation Accuracy: 0.59
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5910 - loss: 1.0232
# Epoch #17	 Training Loss: 1.00	Training Accuracy: 0.62	Validation Loss: 1.02	Validation Accuracy: 0.59
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5880 - loss: 1.0222
# Epoch #18	 Training Loss: 0.98	Training Accuracy: 0.61	Validation Loss: 1.02	Validation Accuracy: 0.59
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6000 - loss: 1.0074
# Epoch #19	 Training Loss: 0.97	Training Accuracy: 0.61	Validation Loss: 1.01	Validation Accuracy: 0.60
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6060 - loss: 1.0095
# Epoch #20	 Training Loss: 0.96	Training Accuracy: 0.63	Validation Loss: 1.01	Validation Accuracy: 0.61
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6150 - loss: 1.0068
# Epoch #21	 Training Loss: 0.97	Training Accuracy: 0.62	Validation Loss: 1.01	Validation Accuracy: 0.62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6140 - loss: 1.0024
# Epoch #22	 Training Loss: 0.96	Training Accuracy: 0.63	Validation Loss: 1.00	Validation Accuracy: 0.61
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6160 - loss: 1.0001
# Epoch #23	 Training Loss: 0.94	Training Accuracy: 0.63	Validation Loss: 1.00	Validation Accuracy: 0.62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6210 - loss: 0.9917
# Epoch #24	 Training Loss: 0.94	Training Accuracy: 0.63	Validation Loss: 0.99	Validation Accuracy: 0.62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6170 - loss: 0.9878
# Epoch #25	 Training Loss: 0.93	Training Accuracy: 0.64	Validation Loss: 0.99	Validation Accuracy: 0.62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6130 - loss: 0.9887
# Epoch #26	 Training Loss: 0.93	Training Accuracy: 0.64	Validation Loss: 0.99	Validation Accuracy: 0.61
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6260 - loss: 0.9822
# Epoch #27	 Training Loss: 0.92	Training Accuracy: 0.64	Validation Loss: 0.98	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6220 - loss: 0.9796
# Epoch #28	 Training Loss: 0.92	Training Accuracy: 0.64	Validation Loss: 0.98	Validation Accuracy: 0.62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6230 - loss: 0.9809
# Epoch #29	 Training Loss: 0.91	Training Accuracy: 0.65	Validation Loss: 0.98	Validation Accuracy: 0.62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6270 - loss: 0.9779
# Epoch #30	 Training Loss: 0.90	Training Accuracy: 0.65	Validation Loss: 0.98	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6370 - loss: 0.9801
# Epoch #31	 Training Loss: 0.90	Training Accuracy: 0.65	Validation Loss: 0.98	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6380 - loss: 0.9715
# Epoch #32	 Training Loss: 0.88	Training Accuracy: 0.66	Validation Loss: 0.97	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6340 - loss: 0.9722
# Epoch #33	 Training Loss: 0.89	Training Accuracy: 0.66	Validation Loss: 0.97	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6260 - loss: 0.9696
# Epoch #34	 Training Loss: 0.89	Training Accuracy: 0.65	Validation Loss: 0.97	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6230 - loss: 0.9676
# Epoch #35	 Training Loss: 0.88	Training Accuracy: 0.66	Validation Loss: 0.97	Validation Accuracy: 0.62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6200 - loss: 0.9655
# Epoch #36	 Training Loss: 0.88	Training Accuracy: 0.67	Validation Loss: 0.97	Validation Accuracy: 0.62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6310 - loss: 0.9687
# Epoch #37	 Training Loss: 0.88	Training Accuracy: 0.66	Validation Loss: 0.97	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6300 - loss: 0.9709
# Epoch #38	 Training Loss: 0.88	Training Accuracy: 0.66	Validation Loss: 0.97	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6270 - loss: 0.9733
# Epoch #39	 Training Loss: 0.86	Training Accuracy: 0.66	Validation Loss: 0.97	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6300 - loss: 0.9662
# Epoch #40	 Training Loss: 0.86	Training Accuracy: 0.67	Validation Loss: 0.97	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6330 - loss: 0.9661
# Epoch #41	 Training Loss: 0.86	Training Accuracy: 0.67	Validation Loss: 0.97	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6320 - loss: 0.9590
# Epoch #42	 Training Loss: 0.86	Training Accuracy: 0.67	Validation Loss: 0.96	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6330 - loss: 0.9617
# Epoch #43	 Training Loss: 0.85	Training Accuracy: 0.67	Validation Loss: 0.96	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6340 - loss: 0.9592
# Epoch #44	 Training Loss: 0.85	Training Accuracy: 0.67	Validation Loss: 0.96	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6290 - loss: 0.9587
# Epoch #45	 Training Loss: 0.86	Training Accuracy: 0.67	Validation Loss: 0.96	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6410 - loss: 0.9494
# Epoch #46	 Training Loss: 0.85	Training Accuracy: 0.67	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6410 - loss: 0.9465
# Epoch #47	 Training Loss: 0.84	Training Accuracy: 0.67	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6310 - loss: 0.9549
# Epoch #48	 Training Loss: 0.83	Training Accuracy: 0.68	Validation Loss: 0.95	Validation Accuracy: 0.63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6370 - loss: 0.9590
# Epoch #49	 Training Loss: 0.82	Training Accuracy: 0.68	Validation Loss: 0.96	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6370 - loss: 0.9578
# Epoch #50	 Training Loss: 0.83	Training Accuracy: 0.68	Validation Loss: 0.96	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6400 - loss: 0.9490
# Epoch #51	 Training Loss: 0.83	Training Accuracy: 0.68	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6450 - loss: 0.9472
# Epoch #52	 Training Loss: 0.82	Training Accuracy: 0.69	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6450 - loss: 0.9450
# Epoch #53	 Training Loss: 0.83	Training Accuracy: 0.68	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6420 - loss: 0.9450
# Epoch #54	 Training Loss: 0.82	Training Accuracy: 0.69	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6460 - loss: 0.9429
# Epoch #55	 Training Loss: 0.81	Training Accuracy: 0.69	Validation Loss: 0.94	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6480 - loss: 0.9337
# Epoch #56	 Training Loss: 0.81	Training Accuracy: 0.69	Validation Loss: 0.93	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6380 - loss: 0.9407
# Epoch #57	 Training Loss: 0.80	Training Accuracy: 0.69	Validation Loss: 0.94	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6450 - loss: 0.9356
# Epoch #58	 Training Loss: 0.80	Training Accuracy: 0.70	Validation Loss: 0.94	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6450 - loss: 0.9388
# Epoch #59	 Training Loss: 0.80	Training Accuracy: 0.69	Validation Loss: 0.94	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6500 - loss: 0.9340
# Epoch #60	 Training Loss: 0.80	Training Accuracy: 0.69	Validation Loss: 0.93	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6460 - loss: 0.9371
# Epoch #61	 Training Loss: 0.79	Training Accuracy: 0.70	Validation Loss: 0.94	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6430 - loss: 0.9329
# Epoch #62	 Training Loss: 0.79	Training Accuracy: 0.70	Validation Loss: 0.93	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6470 - loss: 0.9452
# Epoch #63	 Training Loss: 0.78	Training Accuracy: 0.70	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6400 - loss: 0.9456
# Epoch #64	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6430 - loss: 0.9525
# Epoch #65	 Training Loss: 0.78	Training Accuracy: 0.70	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6460 - loss: 0.9579
# Epoch #66	 Training Loss: 0.79	Training Accuracy: 0.70	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6470 - loss: 0.9551
# Epoch #67	 Training Loss: 0.77	Training Accuracy: 0.71	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6430 - loss: 0.9529
# Epoch #68	 Training Loss: 0.78	Training Accuracy: 0.70	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6510 - loss: 0.9456
# Epoch #69	 Training Loss: 0.78	Training Accuracy: 0.70	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6470 - loss: 0.9441
# Epoch #70	 Training Loss: 0.78	Training Accuracy: 0.70	Validation Loss: 0.94	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6440 - loss: 0.9460
# Epoch #71	 Training Loss: 0.77	Training Accuracy: 0.70	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6490 - loss: 0.9536
# Epoch #72	 Training Loss: 0.78	Training Accuracy: 0.69	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6470 - loss: 0.9485
# Epoch #73	 Training Loss: 0.77	Training Accuracy: 0.70	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6390 - loss: 0.9487
# Epoch #74	 Training Loss: 0.77	Training Accuracy: 0.70	Validation Loss: 0.95	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6420 - loss: 0.9577
# Epoch #75	 Training Loss: 0.77	Training Accuracy: 0.71	Validation Loss: 0.96	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6430 - loss: 0.9561
# Epoch #76	 Training Loss: 0.75	Training Accuracy: 0.71	Validation Loss: 0.96	Validation Accuracy: 0.64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6510 - loss: 0.9525
# Epoch #77	 Training Loss: 0.76	Training Accuracy: 0.71	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6520 - loss: 0.9578
# Epoch #78	 Training Loss: 0.76	Training Accuracy: 0.71	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6510 - loss: 0.9603
# Epoch #79	 Training Loss: 0.76	Training Accuracy: 0.71	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6610 - loss: 0.9438
# Epoch #80	 Training Loss: 0.77	Training Accuracy: 0.71	Validation Loss: 0.94	Validation Accuracy: 0.66
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6490 - loss: 0.9482
# Epoch #81	 Training Loss: 0.77	Training Accuracy: 0.70	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6490 - loss: 0.9487
# Epoch #82	 Training Loss: 0.76	Training Accuracy: 0.71	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6570 - loss: 0.9495
# Epoch #83	 Training Loss: 0.75	Training Accuracy: 0.71	Validation Loss: 0.95	Validation Accuracy: 0.66
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6560 - loss: 0.9515
# Epoch #84	 Training Loss: 0.75	Training Accuracy: 0.72	Validation Loss: 0.95	Validation Accuracy: 0.66
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6510 - loss: 0.9568
# Epoch #85	 Training Loss: 0.74	Training Accuracy: 0.72	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6570 - loss: 0.9521
# Epoch #86	 Training Loss: 0.74	Training Accuracy: 0.72	Validation Loss: 0.95	Validation Accuracy: 0.66
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6540 - loss: 0.9515
# Epoch #87	 Training Loss: 0.73	Training Accuracy: 0.73	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6560 - loss: 0.9567
# Epoch #88	 Training Loss: 0.74	Training Accuracy: 0.72	Validation Loss: 0.96	Validation Accuracy: 0.66
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6540 - loss: 0.9599
# Epoch #89	 Training Loss: 0.73	Training Accuracy: 0.72	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6530 - loss: 0.9511
# Epoch #90	 Training Loss: 0.73	Training Accuracy: 0.73	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6460 - loss: 0.9540
# Epoch #91	 Training Loss: 0.74	Training Accuracy: 0.72	Validation Loss: 0.95	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6460 - loss: 0.9628
# Epoch #92	 Training Loss: 0.73	Training Accuracy: 0.72	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6470 - loss: 0.9658
# Epoch #93	 Training Loss: 0.72	Training Accuracy: 0.73	Validation Loss: 0.97	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6520 - loss: 0.9577
# Epoch #94	 Training Loss: 0.73	Training Accuracy: 0.72	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6520 - loss: 0.9557
# Epoch #95	 Training Loss: 0.73	Training Accuracy: 0.73	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6510 - loss: 0.9632
# Epoch #96	 Training Loss: 0.73	Training Accuracy: 0.72	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6510 - loss: 0.9678
# Epoch #97	 Training Loss: 0.73	Training Accuracy: 0.73	Validation Loss: 0.97	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6520 - loss: 0.9611
# Epoch #98	 Training Loss: 0.73	Training Accuracy: 0.73	Validation Loss: 0.96	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6490 - loss: 0.9677
# Epoch #99	 Training Loss: 0.73	Training Accuracy: 0.72	Validation Loss: 0.97	Validation Accuracy: 0.65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6480 - loss: 0.9629
# Epoch #100	 Training Loss: 0.74	Training Accuracy: 0.72	Validation Loss: 0.96	Validation Accuracy: 0.65

# %%
### Run once after you have finished training your model ###

nn_pred = model.predict(test_data)
rf_pred = random_forest.predict_proba(test_data)
test_pred = (nn_pred + rf_pred) / 2
test_output = np.ndarray(shape = (1000, 6))

# """ Add column with file number """
for i in range(1000):
    test_output[i] = np.append(test_pred[i], test_order[i])
test_dataframe = pd.DataFrame(test_output)

""" Sort dataframe according to file number """
sorted_test_dataframe = test_dataframe.sort_values(by=[5])

""" Drop file number column """
processed_test_dataframe = sorted_test_dataframe.drop(sorted_test_dataframe.columns[5], axis=1)

print(test_dataframe.head(), '\n\n', sorted_test_dataframe.head(), '\n\n', processed_test_dataframe.head())

file = 'SquashisGreatL.xz'
processed_test_dataframe.to_pickle(file)
test_dataframe = pd.DataFrame(test_output)
os.listdir('.')
files.download(file)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#           0         1         2         3         4    5
# 0  0.020006  0.002001  0.045206  0.931788  0.001000  0.0
# 1  0.629742  0.259065  0.054197  0.019643  0.037353  1.0
# 2  0.066999  0.545562  0.251799  0.002197  0.133444  2.0
# 3  0.322235  0.081268  0.302098  0.083838  0.210560  3.0
# 4  0.617632  0.156708  0.086471  0.101608  0.037582  4.0
#
#            0         1         2         3         4    5
# 0  0.020006  0.002001  0.045206  0.931788  0.001000  0.0
# 1  0.629742  0.259065  0.054197  0.019643  0.037353  1.0
# 2  0.066999  0.545562  0.251799  0.002197  0.133444  2.0
# 3  0.322235  0.081268  0.302098  0.083838  0.210560  3.0
# 4  0.617632  0.156708  0.086471  0.101608  0.037582  4.0
#
#            0         1         2         3         4
# 0  0.020006  0.002001  0.045206  0.931788  0.001000
# 1  0.629742  0.259065  0.054197  0.019643  0.037353
# 2  0.066999  0.545562  0.251799  0.002197  0.133444
# 3  0.322235  0.081268  0.302098  0.083838  0.210560
# 4  0.617632  0.156708  0.086471  0.101608  0.037582

# %% [markdown]
# ## Submitting Your Model
#
# After training your classifier, run it on the test data to generate your predictions. Each class for a test sample should have an associated probability (between 0 and 1). Below are the parameters for the prediction format and export:
#
# - Your predictions should be in a pandas dataframe with 5 columns (classes) and 1000 rows (samples). Note that your predictions must follow the original test sample order (0.xz, 1.xz, 2.xz, ...). You only need to worry about this if you shuffled the test samples or stored the samples in an unordered data structure (dictionaries and sets). If this is the case, you should 1) add a separate column in your pandas dataframe with the file number for each sample; 2) sort the dataframe using this column; and 3) drop the column. These steps have been noted in the code below.
# - The predictions dataframe should be exported as an .xz file using dataframe.to_pickle() followed by files.download().
#
# Example code of the prediction format and export is presented in the cell block below.

# %% [markdown]
# Your model will be evaluated on Area Under the ROC Curve (ROCAUC), Matthews Correlation Coefficient (MCC) and creativity. There will be a "winning" group for each of these categories.
#
# If you are finished early, consider trying other ML algorithms and/or implementing multiple feature extraction methods. You can also help other groups if you finish early.

# %% [markdown]
# ## How Your Model Will Be Evaluated
#
# - **Area Under the ROC Curve (AUCROC)**: The receiver operating characteristic (ROC) curve plots the true positive rate (sensitivity/recall) against the false positive rate (fall-out) at many decision threshold settings. The area under the curve (AUC) measures discrimination, the classifier's ability to correctly identify samples from the "positive" and "negative" cases. Intuitively, AUC is the probability that a randomly chosen "positive" sample will be labeled as "more positive" than a randomly chosen "negative" sample. In the case of a multi-class ROC curve, each class is considered separately before taking the weighted average of all the class results. Simply put, the class under consideration is labeled as "positive" while all other classes are labeled as "negative." Below is the multi-class ROC curve for the example classifier. The AUCROC score should be between 0 and 1, in which 0.5 is random classification and 1 is perfect classification.
#
# <img src="https://github.com/BeaverWorksMedlytics2020/Data_Public/blob/master/Images/Week2/MultiClassRocCurve_exampleClassifier.png?raw=true" width="600" height="500">
#
# - **Matthews Correlation Coefficient (MCC)**: The MCC measures the quality of binary classifications, irrespective of the class sizes. Importantly, it is typically regarded as a balanced measure since it considers all values in the 2x2 contingency table (TP, FP, TN, FN). For this challenge, the binary classes will be "Arousal" (Arousal) and "Nonarousal" (NREM1, NREM2, NREM3, REM). The MCC score should be between -1 and 1, in which 0 is random classification and 1 is perfect classification.
#
#  ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/5caa90fc15105b74b59a30bbc9cc2e5bd43a13b7)
#
# Using these metrics, the example classifier has the following scores on test data:
# - AUCROC: 0.727
# - MCC: 0.163
# - Creativity: ( ͡° ͜ʖ ͡°)
#
# Below is the code used to calculate the AUCROC and MCC metrics when evaluating your classifier.

# %%
test_pred = pd.DataFrame(model.predict(mocktest_data))
test_predict = test_pred.idxmax(axis=1)
test_labels = [ np.where(label==1)[0][0] for label in mocktest_labels]
test_labels_one_hot = pd.DataFrame(mocktest_labels)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print(np.isnan(train_data).any())
print(np.isnan(test_data).any())
# Out:
# False
# False

# %%
fpr = {}
tpr = {}
roc_auc = {}

plt.figure(figsize=(14,10))
for i in range(5):
    fpr[i], tpr[i], _ = metrics.roc_curve(test_labels_one_hot.iloc[:, i], test_pred.iloc[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i], label = stage_dict[i] + ', ' + str(i))

plt.plot([0, 1], [0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend()
plt.show()

fpr["micro"], tpr["micro"], _ = metrics.roc_curve(test_labels_one_hot.values.ravel(), test_pred.values.ravel())
roc_auc_agg = metrics.auc(fpr["micro"], tpr["micro"])

# %%
y_true = []
y_pred = []
for i in range(test_pred.shape[0]):
    if test_predict.iloc[i]==0: y_pred.append(1)
    else: y_pred.append(-1)
    if test_labels[i]==0: y_true.append(1)
    else: y_true.append(-1)
mcc = metrics.matthews_corrcoef(y_true, y_pred)

# %%
print(roc_auc_agg, mcc)
# Out:
# 0.8960919999999999 0.4020944707324396
